# %%
# standard data science imports with abbreviations
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt

# %matplotlib inline

# %%
PATH = '../data/SalaryData.csv'

# %%
df = pd.read_csv(PATH)
df.head(20)
# Out:
#     SalaryDataID  CalendarYear        EmployeeName  \
# 0              1          2008     Butler, Matthew
# 1              2          2008     Mroskey, Carrie
# 2              3          2008        Trees, Kevin
# 3              4          2009         Final, Mark
# 4              5          2009       Monroe, Mable
# 5              6          2008        Geary, Danny
# 6              7          2008  Pendigraph, Rhonda
# 7              8          2008     Stephens, Debra
# 8              9          2008     Arnold, Richard
# 9             10          2008        Long, Bonnie
# 10            11          2010        Stalvey, Roy
# 11            12          2010      Dixon, Michael
# 12            13          2009      Langford, Lisa
# 13            14          2009        Stalvey, Roy
# 14            15          2009         Lopez, Joel
# 15            16          2009      Bishop, Conrad
# 16            17          2009        Sloan, Amber
# ...

# %%
df[(df['EmployeeName'].str.contains(", Eva")) & ~(df['EmployeeName'].str.contains(", Evan"))]
# Out:
#        SalaryDataID  CalendarYear    EmployeeName                Department  \
# 15638         15639          2009     Morgan, Eva   Louisville Metro Police
# 15648         15649          2010     Morgan, Eva   Louisville Metro Police
# 15656         15657          2008     Morgan, Eva   Louisville Metro Police
# 15669         15670          2011     Morgan, Eva   Louisville Metro Police
# 18875         18876          2009    Addison, Eva     Air Pollution Control
# 19841         19842          2010    Addison, Eva     Air Pollution Control
# 19857         19858          2019    Addison, Eva     Air Pollution Control
# 22601         22602          2011       Tapp, Eva            Mayor's Office
# 22614         22615          2010       Tapp, Eva            Mayor's Office
# 22629         22630          2008       Tapp, Eva            Mayor's Office
# 35946         35947          2011    Addison, Eva     Air Pollution Control
# ...

# %%
df.columns
# Out:
# Index(['SalaryDataID', 'CalendarYear', 'EmployeeName', 'Department',
#        'JobTitle', 'AnnualRate', 'RegularRate', 'OvertimeRate',
#        'IncentiveAllowance', 'Other', 'YearToDate'],
#       dtype='object')

# %%
df.describe()
# Out:
#        SalaryDataID  CalendarYear     AnnualRate    RegularRate  \
# count  86875.000000  86875.000000   86875.000000   86875.000000
# mean   43438.000000   2013.409669   41952.119271   34611.849618
# std    25078.796655      3.466214   18043.845078   20411.341331
# min        1.000000   2008.000000    1300.000000    -542.100000
# 25%    21719.500000   2010.000000   32094.400000   21050.945000
# 50%    43438.000000   2013.000000   42105.860000   35977.790000
# 75%    65156.500000   2016.000000   51604.800000   47528.000000
# max    86875.000000   2019.000000  178339.200000  184752.180000
#
#         OvertimeRate  IncentiveAllowance         Other     YearToDate
# count   86875.000000        86875.000000  86875.000000   86875.000000
# mean     3587.457555         1866.303937   1022.054321   41087.665431
# std      6822.738956         3178.499590   4489.397916   24709.942718
# min      -249.040000         -207.150000 -28699.390000  -28699.390000
# ...

# %%
import random
comp_pick = random.randint(1,100)
count = 0
while count == 0 or comp_pick != user_guess:
    user_guess = int(input(f"{None or msg} 1-100, What's your guess?\n"))
    msg = "Too high!" if user_guess > comp_pick else "Too low!"
    count += 1
print(f"Correct the number is {comp_pick}, it took you {count} guesses!")
